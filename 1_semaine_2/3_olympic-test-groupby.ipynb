# %%
import pandas as pd
import numpy as np
athletes = pd.read_csv('../../data/athlete_events.csv')

# %% [markdown]
# # Round

# %%
athletes.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
athletes['Year'] = athletes['Year'].round(-1)
athletes.head()
sport_table = athletes[['Year','Sport']].groupby(['Year','Sport']).size().unstack()
# sport_table.columns.values
sport_table['Golf']
# Out:
# Year
# 1900    127.0
# 1910      NaN
# 1920      NaN
# 1930      NaN
# 1940      NaN
# 1950      NaN
# 1960      NaN
# 1970      NaN
# 1980      NaN
# 1990      NaN
# 2000      NaN
# 2010      NaN
# 2020    120.0
# Name: Golf, dtype: float64

# %%
#pd.DataFrame(athletes[athletes['Season']=='Summer']['Sport'].unique()).sort_values(0)
athletes[athletes['Sport']=='Golf']
# Out:
#             ID                                       Name Sex   Age  Height  \
# 283        150              Margaret Ives Abbott (-Dunne)   F  23.0     NaN
# 284        151        Mary Perkins Ives Abbott (Perkins-)   F  42.0     NaN
# 1449       806                   Bartlett S. "Bart" Adams   M  38.0     NaN
# 2247      1244                      Felipe Aguilar Schler   M  41.0   170.0
# 4979      2842               Henry Woodward "Harry" Allen   M  27.0     NaN
# 5112      2906                                Louis Allis   M  37.0     NaN
# 6367      3569                              An Byeong-Hun   M  24.0   186.0
# 7812      4330                     Clarence Victor Angier   M  50.0     NaN
# 7978      4417                       Alfred Heacock Annan   M  29.0     NaN
# 8533      4691                       Kiradech Aphibarnrat   M  27.0   172.0
# 10177     5562                                Aditi Ashok   F  18.0   173.0
# ...

# %%
sport_table
# Out:
# Sport  Aeronautics  Alpine Skiing  Alpinism  Archery  Art Competitions  \
# Year
# 1900           NaN            NaN       NaN    102.0               NaN
# 1910           NaN            NaN       NaN     77.0              33.0
# 1920           NaN            NaN      21.0     86.0             329.0
# 1930           NaN            NaN       2.0      NaN            1932.0
# 1940           1.0          103.0       2.0      NaN             813.0
# 1950           NaN          738.0       NaN      NaN             471.0
# 1960           NaN         1134.0       NaN      NaN               NaN
# 1970           NaN          747.0       NaN     95.0               NaN
# 1980           NaN         1118.0       NaN    240.0               NaN
# 1990           NaN         1962.0       NaN    504.0               NaN
# 2000           NaN         1036.0       NaN    636.0               NaN
# 2010           NaN         1991.0       NaN    394.0               NaN
# ...

# %%
sport_table.count().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-daca347d81b7> in <module>()
# ----> 1 sport_table.count().sort_values(ascending=False)
#
# NameError: name 'sport_table' is not defined

# %%
sport_table.isna()==False
# Out:
# Sport  Aeronautics  Alpine Skiing  Alpinism  Archery  Art Competitions  \
# Year
# 1900         False          False     False     True             False
# 1910         False          False     False     True              True
# 1920         False          False      True     True              True
# 1930         False          False      True    False              True
# 1940          True           True      True    False              True
# 1950         False           True     False    False              True
# 1960         False           True     False    False             False
# 1970         False           True     False     True             False
# 1980         False           True     False     True             False
# 1990         False           True     False     True             False
# 2000         False           True     False     True             False
# 2010         False           True     False     True             False
# ...
