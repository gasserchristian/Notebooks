# %% [markdown]
# # Requests
# Une petite introduction à la librairie request

# %%
import requests
r = requests.get('https://api.github.com/events')
print(r)
# Out:
# <Response [200]>

# %%
type(r)
# Out:
# requests.models.Response

# %%
r.json()
# Out:
# [{'id': '8115405240',
#   'type': 'PushEvent',
#   'actor': {'id': 42396005,
#    'login': 'clf1043457163aa',
#    'display_login': 'clf1043457163aa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/clf1043457163aa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42396005?'},
#   'repo': {'id': 144814660,
#    'name': 'clf1043457163aa/hello-github',
#    'url': 'https://api.github.com/repos/clf1043457163aa/hello-github'},
#   'payload': {'push_id': 2798431080,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7bc6590dc639ce048b9e8e24f49b04392613c425',
#    'before': 'b85519744476fc384a3d587627d99937ee81c86f',
#    'commits': [{'sha': '7bc6590dc639ce048b9e8e24f49b04392613c425',
#      'author': {'email': 'clf1043457163aa@gmail.com',
#       'name': 'clf1043457163aa'},
#      'message': 'repository update',
#      'distinct': True,
# ...
