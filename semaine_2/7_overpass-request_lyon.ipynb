# %% [markdown]
# __Step 1 :__ importer request, pandas, numpy et matplot

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# __Step 2 :__ requête sur overpass avec output json, nodes dans area défini par un Wikidata ID == hydrater

# %%
wikidata = 'Q18338206'
r_url = '%5Bout%3Ajson%5D%3B%0D%0Aarea%5Bwikidata%3D'+wikidata+'%5D%3B%0D%0Anode%28area%29%5B%7E%27%5Ba-z0-9%5D%27%7E%27%5Ba-z0-9%5D%27%5D%3B%0D%0Aout%3B'
r = requests.get('https://www.overpass-api.de/api/interpreter?data='+r_url)
jsonobject = r.json()
elements = jsonobject['elements']

# %%
'''df = pd.DataFrame(relations['elements'])
df = df.drop(columns=['type','id'])
dict = df.to_dict()
dict = dict['tags']'''
# Out:
# "df = pd.DataFrame(relations['elements'])\ndf = df.drop(columns=['type','id'])\ndict = df.to_dict()\ndict = dict['tags']"

# %%
len(elements)
# Out:
# 1572221

# %%
table = list()
for element in elements: # elements isolé
    for tag, value in element['tags'].items():
        table.append([element['id'],element['lat'],element['lon'],element['type'],tag,value])

# %%
df = pd.DataFrame(table,columns=['id','lat','lon','type','tag','value'])

# %% [markdown]
# __Step 3 :__ statistique sur la fréquence des tags

# %%
print(len(df['tag'].value_counts()))
c = df['tag'].value_counts().head()
c
# Out:
# 1845
# source              980620
# addr:housenumber    343398
# name                173281
# natural             124969
# power               114475
# Name: tag, dtype: int64

# %% [markdown]
# __Step 4 :__ filtre spécifique, écriture de fonction
# - filtre. entrée : colonne, valeur. Correspondance avec ID
# - idée : fonction qui enlève éléments qui a un certain Tag

# %%
def selectClusters(df, column='tag', value='name'):
    idswithavalueincolumn = df[df[column]==value]['id']
    filtered = df[df['id'].isin(idswithavalueincolumn)]
    return filtered[filtered[column] != value]

# %% [markdown]
# __-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------__

# %%
selectClusters(df,'value','monastery')['tag'].value_counts()
# Out:
# name                    19
# heritage:operator       17
# wikidata                17
# ref:mhs                 17
# source:heritage         16
# mhs:inscription_date    14
# heritage                14
# start_date              10
# wikipedia                9
# monastery:type           5
# ruins                    2
# religious_rank           2
# tourism                  2
# image                    1
# access                   1
# source                   1
# name:ru                  1
# barrier                  1
# community                1
# alt_name                 1
# name:es                  1
# Name: tag, dtype: int64

# %%
df[df['value']=='monastery']['tag'].value_counts().sort_index()
# Out:
# amenity      5
# historic    17
# Name: tag, dtype: int64

# %%
selectClusters(df,'value','monastery')
# Out:
#                  id        lat       lon  type                   tag  \
# 626464    579881278  45.822609  4.779910  node             community
# 626465    579881278  45.822609  4.779910  node                  name
# 799238    749938395  45.941504  3.520077  node                access
# 799239    749938395  45.941504  3.520077  node               barrier
# 799240    749938395  45.941504  3.520077  node              heritage
# 799241    749938395  45.941504  3.520077  node     heritage:operator
# 799243    749938395  45.941504  3.520077  node  mhs:inscription_date
# 799244    749938395  45.941504  3.520077  node                  name
# 799245    749938395  45.941504  3.520077  node               ref:mhs
# 799246    749938395  45.941504  3.520077  node        religious_rank
# 799247    749938395  45.941504  3.520077  node                source
# 799248    749938395  45.941504  3.520077  node       source:heritage
# 799249    749938395  45.941504  3.520077  node            start_date
# 799250    749938395  45.941504  3.520077  node              wikidata
# 799251    749938395  45.941504  3.520077  node             wikipedia
# 1021845  1613598310  44.729089  4.088600  node                  name
# 1021846  1613598310  44.729089  4.088600  node                 ruins
# 1047940  1697610477  45.363393  5.793303  node              heritage
# 1047941  1697610477  45.363393  5.793303  node     heritage:operator
# 2722462                                                mhs
# 2722464                                            convent
# 2722465                             Couvent des Cordeliers
# 2722466                                         PA00117654
# 2722467       data.gouv.fr, Ministère de la Culture - 2016
# 2722468                                                C14
# 2722469                                          Q22967388
# 2724623         Monastère Orthodoxe Saint-Antoine-le-Grand
# 2851567                     Chartreuse du Val Sainte-Marie
# 2851568                                                yes
# 3054706                                                  3
# 3054707                                                mhs
# 3054709                                         2001-12-03
# 3054710                                            convent
# 3054711               Couvent du chapitre de Saint-Chamant
# 3054712                                         PA15000012
# 3054713       data.gouv.fr, Ministère de la Culture - 2016
# 3054714                                                C15
# 3054715                                          Q22995864
# 3270278                                                  3
# 3270279                                                mhs
# 3270281                                         1999-04-28
# 3270282                                 Abbaye Sainte-Anne
# 3270283                                         PA26000006
# 3270284                                              abbey
# 3270285       data.gouv.fr, Ministère de la Culture - 2016
# 3270286                                                C13
# 3270287                                           Q2820458
# 3270288       fr:Abbaye Sainte-Anne de Bonlieu-sur-Roubion
#
# [152 rows x 6 columns]

# %%
selectClusters(df,'value','monastery')[selectClusters(df,'value','monastery')['tag']=='wikidata']
# Out:
#                  id        lat       lon  type       tag      value
# 799250    749938395  45.941504  3.520077  node  wikidata   Q1113647
# 1047948  1697610477  45.363393  5.793303  node  wikidata    Q180709
# 2038255  3139005258  46.249758  3.331411  node  wikidata   Q2820375
# 2038303  3139079009  46.530597  3.040107  node  wikidata   Q3402991
# 2038730  3140712259  46.211191  3.272654  node  wikidata   Q3402955
# 2193939  3548854536  45.644554  4.045404  node  wikidata  Q22967179
# 2312585  3886714388  45.780930  3.077098  node  wikidata  Q22928146
# 2555780  4595929699  46.534825  3.193277  node  wikidata   Q3402951
# 2617700  4718786845  46.158751  4.161379  node  wikidata  Q22967182
# 2628157  4752262350  45.543176  3.250161  node  wikidata  Q22992200
# 2644418  4793879698  45.798000  4.231300  node  wikidata  Q22996904
# 2647119  4801754958  46.372462  6.480839  node  wikidata   Q3001656
# 2722347  4902377012  45.610254  4.064393  node  wikidata  Q22967250
# 2722453  4902584542  45.737302  4.288652  node  wikidata  Q22996900
# 2722469  4902584556  46.158514  4.161175  node  wikidata  Q22967388
# 3054715  5499467137  45.089171  2.442092  node  wikidata  Q22995864
# 3270287  5834506883  44.594274  4.879668  node  wikidata   Q2820458

# %%
test = selectClusters(df,'value','monastery')[selectClusters(df,'value','monastery')['tag']=='wikidata']['value']

# %%
def f(argument):
    print('https://www.wikidata.org/wiki/'+argument)
test.map(f)
test[799247]
# Out:
# https://www.wikidata.org/wiki/Q1113647
# https://www.wikidata.org/wiki/Q180709
# https://www.wikidata.org/wiki/Q2820375
# https://www.wikidata.org/wiki/Q3402991
# https://www.wikidata.org/wiki/Q3402955
# https://www.wikidata.org/wiki/Q22967179
# https://www.wikidata.org/wiki/Q22928146
# https://www.wikidata.org/wiki/Q3402951
# https://www.wikidata.org/wiki/Q22967182
# https://www.wikidata.org/wiki/Q22992200
# https://www.wikidata.org/wiki/Q22996904
# https://www.wikidata.org/wiki/Q3001656
# https://www.wikidata.org/wiki/Q22967250
# https://www.wikidata.org/wiki/Q22996900
# https://www.wikidata.org/wiki/Q22967388
# https://www.wikidata.org/wiki/Q22995864
# https://www.wikidata.org/wiki/Q2820458
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-4a882e570e6e> in <module>()
#       2     print('https://www.wikidata.org/wiki/'+argument)
#       3 test.map(f)
# ----> 4 test[799247]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     764         key = com._apply_if_callable(key, self)
#     765         try:
# --> 766             result = self.index.get_value(self, key)
#     767
#     768             if not is_scalar(result):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    3101         try:
#    3102             return self._engine.get_value(s, k,
# -> 3103                                           tz=getattr(series.dtype, 'tz', None))
#    3104         except KeyError as e1:
#    3105             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 799247
